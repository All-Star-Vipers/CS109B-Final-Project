# %%
import pandas as pd
from ast import literal_eval
import numpy as np
from sklearn.cross_validation import train_test_split
import itertools

# %%
# load datasets
df_tmdb = pd.read_csv('detailed_movie_data_tmdb_final.csv')
df_imdb = pd.read_csv('detailed_movie_data_imdb_final.csv')

# %%
# filter out records without imdb dataa
df_imdb = df_imdb[df_imdb['movie_status_code'] == True]
print(df_tmdb.shape)
print(df_imdb.shape)
# Out:
# (13386, 18)
# (13383, 19)

# %%
# merge tmdb and imdb
df = df_tmdb.merge(df_imdb, how = 'inner', on = 'imdb_id', suffixes = ('_tmdb', '_imdb'))

# %%
df.shape
# Out:
# (13383, 36)

# %%
# compare titles
df[df['title_tmdb'] !=  df['title_imdb']][['title_imdb', 'title_imdb']]
# Out:
#                                               title_imdb  \
# 0                              [u'Beauty and the Beast']
# 1                                             [u'Logan']
# 2                                              [u'Sing']
# 3                                [u'Kong: Skull Island']
# 4                                    [u'Jurassic World']
# 5           [u'Fantastic Beasts and Where to Find Them']
# 6                                      [u'Finding Dory']
# 7                                [u'Ghost in the Shell']
# 8                                      [u'Interstellar']
# 9                                              [u'Life']
# 10                                            [u'Split']
# 11                          [u'Guardians of the Galaxy']
# 12                       [u'Captain America: Civil War']
# 13                                          [u'Arrival']
# 14                                    [u'The Boss Baby']
# 15                           [u'Underworld: Blood Wars']
# 16                                   [u'Doctor Strange']
# 17                               [u'Mad Max: Fury Road']
# 18                                        [u'Rogue One']
# 19                                         [u'Deadpool']
# 20                                       [u'Four Rooms']
# 21                                   [u'Judgment Night']
# 22                                        [u'Star Wars']
# 23                                     [u'Finding Nemo']
# 24                                     [u'Forrest Gump']
# 25                                  [u'American Beauty']
# 26                                     [u'Citizen Kane']
# 27                               [u'Dancer in the Dark']
# 28                                         [u'The Dark']
# 29                    [u'Le cinqui\xe8me \xe9l\xe9ment']
# ...                                                  ...
# 13213                               [u'William Vincent']
# 13226                             [u'Tian mai zhuan qi']
# 13228                           [u'American Battleship']
# 13233                               [u'Carry on Spying']
# 13234                                    [u'Go with Me']
# 13241                                          [u'Goat']
# 13249            [u'Murder, She Baked: A Deadly Recipe']
# 13250                      [u'Inception: Motion Comics']
# 13256                             [u'Blade: The Series']
# 13263  [u'Ch\xf4jin densetsu Urotsukid\xf4ji: H\xf4r\...
# 13264  [u'Ch\xf4jin densetsu Urotsukidoji V: Kanketsu...
# 13270  [u"Easy Riders, Raging Bulls: How the Sex, Dru...
# 13271                                       [u'Arabesk']
# 13272                                [u'Shark Night 3D']
# 13274  [u'Scooby-Doo! and WWE: Curse of the Speed Dem...
# 13286                            [u'Vokzal dlya dvoikh']
# 13288                                [u"Jusqu'\xe0 toi"]
# 13289                                [u'Die Sklavinnen']
# 13291  [u'Lo and Behold, Reveries of the Connected Wo...
# 13296  [u'Alpha and Omega 4: The Legend of the Saw To...
# 13299                                   [u'Last Sunset']
# 13304                                      [u'Mr. Gibb']
# 13307              [u'Stewie Griffin: The Untold Story']
# 13324                               [u'Kiepie & Kandas']
# 13333                             [u'Dedemin Insanlari']
# 13341                                    [u'Snow White']
# 13343                                      [u'Last Cry']
# 13345                             [u'The Phantom Clone']
# 13359                                    [u'Baka bukas']
# 13375                                  [u'Blue Harvest']
#
#                                               title_imdb
# 0                              [u'Beauty and the Beast']
# 1                                             [u'Logan']
# 2                                              [u'Sing']
# 3                                [u'Kong: Skull Island']
# 4                                    [u'Jurassic World']
# 5           [u'Fantastic Beasts and Where to Find Them']
# 6                                      [u'Finding Dory']
# 7                                [u'Ghost in the Shell']
# 8                                      [u'Interstellar']
# 9                                              [u'Life']
# 10                                            [u'Split']
# 11                          [u'Guardians of the Galaxy']
# 12                       [u'Captain America: Civil War']
# 13                                          [u'Arrival']
# 14                                    [u'The Boss Baby']
# 15                           [u'Underworld: Blood Wars']
# 16                                   [u'Doctor Strange']
# 17                               [u'Mad Max: Fury Road']
# 18                                        [u'Rogue One']
# 19                                         [u'Deadpool']
# 20                                       [u'Four Rooms']
# 21                                   [u'Judgment Night']
# 22                                        [u'Star Wars']
# 23                                     [u'Finding Nemo']
# 24                                     [u'Forrest Gump']
# 25                                  [u'American Beauty']
# 26                                     [u'Citizen Kane']
# 27                               [u'Dancer in the Dark']
# 28                                         [u'The Dark']
# 29                    [u'Le cinqui\xe8me \xe9l\xe9ment']
# ...                                                  ...
# 13213                               [u'William Vincent']
# 13226                             [u'Tian mai zhuan qi']
# 13228                           [u'American Battleship']
# 13233                               [u'Carry on Spying']
# 13234                                    [u'Go with Me']
# 13241                                          [u'Goat']
# 13249            [u'Murder, She Baked: A Deadly Recipe']
# 13250                      [u'Inception: Motion Comics']
# 13256                             [u'Blade: The Series']
# 13263  [u'Ch\xf4jin densetsu Urotsukid\xf4ji: H\xf4r\...
# 13264  [u'Ch\xf4jin densetsu Urotsukidoji V: Kanketsu...
# 13270  [u"Easy Riders, Raging Bulls: How the Sex, Dru...
# 13271                                       [u'Arabesk']
# 13272                                [u'Shark Night 3D']
# 13274  [u'Scooby-Doo! and WWE: Curse of the Speed Dem...
# 13286                            [u'Vokzal dlya dvoikh']
# 13288                                [u"Jusqu'\xe0 toi"]
# 13289                                [u'Die Sklavinnen']
# 13291  [u'Lo and Behold, Reveries of the Connected Wo...
# 13296  [u'Alpha and Omega 4: The Legend of the Saw To...
# 13299                                   [u'Last Sunset']
# 13304                                      [u'Mr. Gibb']
# 13307              [u'Stewie Griffin: The Untold Story']
# 13324                               [u'Kiepie & Kandas']
# 13333                             [u'Dedemin Insanlari']
# 13341                                    [u'Snow White']
# 13343                                      [u'Last Cry']
# 13345                             [u'The Phantom Clone']
# 13359                                    [u'Baka bukas']
# 13375                                  [u'Blue Harvest']
#
# [1429 rows x 2 columns]

# %%
# save raw data
df.to_csv('../Milestone 3/combined_data_full.csv', index = False)

# %%
# convert genre dicts to genre names for tmdb
df['genres_tmdb'] = df['genres_tmdb'].apply(lambda x:[genre['name'] for genre in literal_eval(x)])

# %%
# encode imdb genres in same format as tmdb
df['genres_imdb'] = df['genres_imdb'].apply(lambda x:[genre.encode('utf8') for genre in literal_eval(x)] if x == x else [])

# %%
# view genres
df[df['genres_tmdb'] !=  df['genres_imdb']][['genres_tmdb', 'genres_imdb']]
# Out:
#                                              genres_tmdb  \
# 0                              [Fantasy, Music, Romance]
# 1                       [Action, Drama, Science Fiction]
# 2              [Animation, Comedy, Drama, Family, Music]
# 3          [Science Fiction, Action, Adventure, Fantasy]
# 4         [Action, Adventure, Science Fiction, Thriller]
# 5                           [Adventure, Action, Fantasy]
# 6                 [Adventure, Animation, Comedy, Family]
# 7                       [Action, Drama, Science Fiction]
# 8                    [Adventure, Drama, Science Fiction]
# 9                    [Horror, Science Fiction, Thriller]
# 11                  [Action, Science Fiction, Adventure]
# 12                             [Action, Science Fiction]
# 13                              [Drama, Science Fiction]
# 15                                      [Action, Horror]
# 16         [Action, Adventure, Fantasy, Science Fiction]
# 17        [Action, Adventure, Science Fiction, Thriller]
# 18                 [Action, Drama, Science Fiction, War]
# 19                  [Action, Adventure, Comedy, Romance]
# 20                                       [Crime, Comedy]
# 21                             [Action, Thriller, Crime]
# 22                  [Adventure, Action, Science Fiction]
# 23                                   [Animation, Family]
# 25                                               [Drama]
# 26                                               [Drama]
# 27                                 [Drama, Crime, Music]
# 28                           [Horror, Thriller, Mystery]
# 29     [Adventure, Fantasy, Action, Thriller, Science...
# 31                                         [Documentary]
# 32                          [Adventure, Fantasy, Action]
# 33                                       [Action, Crime]
# ...                                                  ...
# 13345    [Action, Animation, Science Fiction, Adventure]
# 13346              [Animation, Fantasy, Science Fiction]
# 13347             [Adventure, Fantasy, Action, Thriller]
# 13349                                           [Horror]
# 13350                                     [Drama, Music]
# 13352         [Horror, Drama, Thriller, Science Fiction]
# 13353                 [Drama, Science Fiction, Thriller]
# 13354                                 [Action, Thriller]
# 13356                           [Comedy, Drama, Romance]
# 13357          [Science Fiction, Thriller, Drama, Crime]
# 13358               [Fantasy, Adventure, Comedy, Family]
# 13359                                  [Comedy, Romance]
# 13361                       [Fantasy, Thriller, Mystery]
# 13364                       [Adventure, Fantasy, Family]
# 13365                                  [Thriller, Drama]
# 13367                          [Action, Science Fiction]
# 13368                       [Adventure, Fantasy, Action]
# 13369                            [Crime, Drama, Mystery]
# 13370                            [Romance, Drama, Crime]
# 13372        [Fantasy, Comedy, Science Fiction, Romance]
# 13373                           [Horror, Comedy, Family]
# 13374                                [Adventure, Action]
# 13375                                        [Animation]
# 13376                                            [Drama]
# 13377         [Action, Drama, Science Fiction, Thriller]
# 13378                                [Animation, Family]
# 13379                       [Action, Adventure, Romance]
# 13380                                    [Comedy, Drama]
# 13381                                           [Comedy]
# 13382                        [Action, Mystery, Thriller]
#
#                                              genres_imdb
# 0                    [Family, Fantasy, Musical, Romance]
# 1                      [Action, Drama, Sci-Fi, Thriller]
# 2                     [Animation, Comedy, Family, Music]
# 3                   [Action, Adventure, Fantasy, Sci-Fi]
# 4                            [Action, Adventure, Sci-Fi]
# 5                           [Adventure, Family, Fantasy]
# 6                 [Animation, Adventure, Comedy, Family]
# 7      [Action, Crime, Drama, Mystery, Sci-Fi, Thriller]
# 8                             [Adventure, Drama, Sci-Fi]
# 9                             [Horror, Sci-Fi, Thriller]
# 11                           [Action, Adventure, Sci-Fi]
# 12                           [Action, Adventure, Sci-Fi]
# 13                    [Drama, Mystery, Sci-Fi, Thriller]
# 15                          [Action, Adventure, Fantasy]
# 16                  [Action, Adventure, Fantasy, Sci-Fi]
# 17                 [Action, Adventure, Sci-Fi, Thriller]
# 18                           [Action, Adventure, Sci-Fi]
# 19          [Action, Adventure, Comedy, Romance, Sci-Fi]
# 20                                              [Comedy]
# 21                      [Action, Crime, Drama, Thriller]
# 22                  [Action, Adventure, Fantasy, Sci-Fi]
# 23                [Animation, Adventure, Comedy, Family]
# 25                                      [Drama, Romance]
# 26                                      [Drama, Mystery]
# 27                               [Crime, Drama, Musical]
# 28                           [Horror, Mystery, Thriller]
# 29                           [Action, Adventure, Sci-Fi]
# 31                                  [Documentary, Sport]
# 32                          [Action, Adventure, Fantasy]
# 33                             [Action, Crime, Thriller]
# ...                                                  ...
# 13345                                [Animation, Sci-Fi]
# 13346            [Animation, Adventure, Fantasy, Sci-Fi]
# 13347             [Action, Adventure, Fantasy, Thriller]
# 13349                                   [Horror, Sci-Fi]
# 13350                 [Biography, Drama, Music, Romance]
# 13352                                  [Drama, Thriller]
# 13353                          [Drama, Sci-Fi, Thriller]
# 13354                          [Action, Drama, Thriller]
# 13356                                    [Comedy, Drama]
# 13357                          [Crime, Sci-Fi, Thriller]
# 13358  [Animation, Action, Adventure, Comedy, Drama, ...
# 13359                                            [Drama]
# 13361                                [Mystery, Thriller]
# 13364                       [Adventure, Family, Fantasy]
# 13365                                  [Drama, Thriller]
# 13367                                   [Action, Sci-Fi]
# 13368                               [Adventure, Fantasy]
# 13369                   [Crime, Drama, Mystery, Romance]
# 13370           [Crime, Drama, Romance, Sport, Thriller]
# 13372                                  [Comedy, Fantasy]
# 13373                          [Comedy, Family, Fantasy]
# 13374                                           [Action]
# 13375                                [Animation, Comedy]
# 13376                          [Biography, Drama, Music]
# 13377               [Action, Adventure, Fantasy, Sci-Fi]
# 13378                                        [Animation]
# 13379                [Action, Adventure, Drama, Romance]
# 13380                             [Comedy, Drama, Music]
# 13381                                    [Comedy, Sport]
# 13382                          [Action, Crime, Thriller]
#
# [9706 rows x 2 columns]

# %%
# encode genre matrix if movie contains genre
def movie_id_machine(genre_list, genres):
    new_row = []
    for genre in genres:
        if genre in genre_list:
            new_row.append(1)
        else:
            new_row.append(0)
    return new_row

# %%
# encode genre
genres = ["Action", "Adventure", "Animation", "Comedy", "Crime", "Documentary", "Drama", "Family", "Fantasy", "History",
          "Horror", "Music", "Mystery", "Romance", "Science Fiction", "TV Movie", "Thriller", "War", "Western", "Foreign"]
df_genres = df[['genres_tmdb']]
df_genres['genre_encoding'] = df_genres['genres_tmdb'].apply(lambda genres_list: movie_id_machine(genres_list, genres))
df_genres = pd.DataFrame(df_genres['genre_encoding'].tolist(), columns = genres)
df_genres['id'] = df['id']
df_genres.shape
# Out:
# C:\Users\Ihsaan Patel\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (13383, 21)

# %%
df_genres_agg = pd.DataFrame({})
mini_df = []
for column in df_genres.drop('id', axis = 1).columns:
    x = df_genres.drop('id', axis = 1)[df_genres.drop('id', axis = 1)[column] == 1].sum(axis = 0)
    y = x.keys()
    z = x.tolist()
    amounts = {i:j for i,j in zip(y,z)}
    amounts['key_genre'] = column
    mini_df.append(amounts)
df_genres_agg = df_genres_agg.append(mini_df)

# %%
df_genres_agg
# Out:
#     Action  Adventure  Animation  Comedy  Crime  Documentary  Drama  Family  \
# 0     2892       1006        126     591    645           10    926     168
# 1     1006       1775        268     458    134           10    501     474
# 2      126        268        848     314      7            8     52     591
# 3      591        458        314    4245    362           21   1357     680
# 4      645        134          7     362   1682            9    984      17
# 5       10         10          8      21      9          430     31      13
# 6      926        501         52    1357    984           31   5995     309
# 7      168        474        591     680     17           13    309    1378
# 8      289        415        191     365     20            0    274     370
# 9      113         77          4      21     19           15    377       8
# 10     240         72         12     250     97            8    318       7
# 11      21         22         40     192     18           44    225      75
# 12     135         67         13     105    324            3    503      27
# 13     177        153         28    1135    111            0   1450     133
# 14     623        391        113     267     44            2    272     154
# 15      31         24         14      59     10            3    103      63
# 16    1267        399         20     288   1029            5   1564      18
# 17     166         73          4      37      8            5    312       2
# 18     145         70          2      43     16            0    122       7
# 19      36         16          2      37      9            7     66       7
#
#     Fantasy  Foreign       ...         Horror  Music  Mystery  Romance  \
# 0       289       36       ...            240     21      135      177
# 1       415       16       ...             72     22       67      153
# 2       191        2       ...             12     40       13       28
# 3       365       37       ...            250    192      105     1135
# 4        20        9       ...             97     18      324      111
# 5         0        7       ...              8     44        3        0
# 6       274       66       ...            318    225      503     1450
# 7       370        7       ...              7     75       27      133
# 8      1068        8       ...            149     36       51      158
# 9         3        5       ...              4     11        7       64
# 10      149        9       ...           1837     11      273       43
# 11       36        3       ...             11    457        6      152
# 12       51        3       ...            273      6     1009       75
# 13      158       30       ...             43    152       75     2223
# 14      272        4       ...            361      8       90       84
# 15       32        0       ...             25     11       33       52
# 16      136       23       ...            929     15      697      207
# 17        3        2       ...              5      4        8       70
# 18        6        2       ...             11      7        6       42
# 19        8      124       ...              9      3        3       30
#
#     Science Fiction  TV Movie  Thriller  War  Western        key_genre
# 0               623        31      1267  166      145           Action
# 1               391        24       399   73       70        Adventure
# 2               113        14        20    4        2        Animation
# 3               267        59       288   37       43           Comedy
# 4                44        10      1029    8       16            Crime
# 5                 2         3         5    5        0      Documentary
# 6               272       103      1564  312      122            Drama
# 7               154        63        18    2        7           Family
# 8               272        32       136    3        6          Fantasy
# 9                 1        13        42  125       14          History
# 10              361        25       929    5       11           Horror
# 11                8        11        15    4        7            Music
# 12               90        33       697    8        6          Mystery
# 13               84        52       207   70       42          Romance
# 14             1395        31       492    6        6  Science Fiction
# 15               31       248        37    4        5         TV Movie
# 16              492        37      3554   71       32         Thriller
# 17                6         4        71  408       12              War
# 18                6         5        32   12      293          Western
# 19                4         0        23    2        2          Foreign
#
# [20 rows x 21 columns]

# %%
all_genres =  []
for i in range(df_genres_agg.shape[0]):
    for j in df_genres_agg.drop('key_genre', axis = 1).columns:
        grouping = df_genres_agg.iloc[i]['key_genre'] + ' - ' + j
        all_genres.append([grouping, int(df_genres_agg.iloc[i][j])])
all_genres = pd.DataFrame(all_genres, columns = ['genre', 'count'])
all_genres['genre_encoding'] = all_genres['genre'].apply(lambda x: sorted(x.split(' - ')))
all_genres['genre'] = all_genres.apply(lambda row: row['genre_encoding'][0] if row['genre_encoding'][0] == row['genre_encoding'][1] else row['genre'], axis = 1) 
all_genres['genre_encoding'] = all_genres['genre_encoding'].astype(str)
all_genres = all_genres.drop_duplicates('genre_encoding')
all_genres = all_genres.drop('genre_encoding', axis = 1)

# %%
all_genres = all_genres.sort('count', ascending = False)
all_genres.iloc[:25]
# Out:
# C:\Users\Ihsaan Patel\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                   genre  count
# 126               Drama   5995
# 63               Comedy   4245
# 337            Thriller   3554
# 0                Action   2892
# 274             Romance   2223
# 211              Horror   1837
# 21            Adventure   1775
# 84                Crime   1682
# 137    Drama - Thriller   1564
# 134     Drama - Romance   1450
# 295     Science Fiction   1395
# 147              Family   1378
# 66       Comedy - Drama   1357
# 17    Action - Thriller   1267
# 74     Comedy - Romance   1135
# 168             Fantasy   1068
# 97     Crime - Thriller   1029
# 253             Mystery   1009
# 1    Action - Adventure   1006
# 86        Crime - Drama    984
# 217   Horror - Thriller    929
# 6        Action - Drama    926
# 42            Animation    848
# 257  Mystery - Thriller    697
# 67      Comedy - Family    680

# %%
genres_num = all_genres.iloc[:25].as_matrix()
genres_num = {i[0]:i[1] for i in genres_num}
genres_num
# Out:
# {'Action': 2892L,
#  'Action - Adventure': 1006L,
#  'Action - Drama': 926L,
#  'Action - Thriller': 1267L,
#  'Adventure': 1775L,
#  'Animation': 848L,
#  'Comedy': 4245L,
#  'Comedy - Drama': 1357L,
#  'Comedy - Family': 680L,
#  'Comedy - Romance': 1135L,
#  'Crime': 1682L,
#  'Crime - Drama': 984L,
#  'Crime - Thriller': 1029L,
#  'Drama': 5995L,
#  'Drama - Romance': 1450L,
#  'Drama - Thriller': 1564L,
#  'Family': 1378L,
#  'Fantasy': 1068L,
#  'Horror': 1837L,
#  'Horror - Thriller': 929L,
#  'Mystery': 1009L,
#  'Mystery - Thriller': 697L,
#  'Romance': 2223L,
#  'Science Fiction': 1395L,
#  'Thriller': 3554L}

# %%
# choose single genre as outcome variable
def get_genre(tmdb_genres, imdb_genres, genres_num):
    intersection = list(set(tmdb_genres).intersection(set(imdb_genres)))
    if len(intersection) == 0:
        if len(tmdb_genres) > 0:
            intersection = tmdb_genres
        else:
            intersection = imdb_genres
    if len(intersection) == 1:
        return intersection[0]
    else:
        max_genre_count = 0
        max_genre = ''
        for combo in itertools.combinations(intersection, 2):
            combo = sorted(combo)
            genre = combo[0] + ' - ' + combo[1]
            if genre in genres_num.keys():
                if genres_num[genre] > max_genre_count:
                    max_genre_count = genres_num[genre]
                    max_genre = genre
        if max_genre_count == 0:      
            for genre in intersection:
                if genre in genres_num.keys():
                    if genres_num[genre] > max_genre_count:
                        max_genre_count = genres_num[genre]
                        max_genre = genre
        return max_genre

# %%
# choose single genre as outcome variable
df['genre_intersect'] = df.apply(lambda row: get_genre(row['genres_tmdb'], row['genres_imdb'], genres_num), axis = 1)

# %%
df['genre_intersect'].value_counts()
# Out:
# Drama                 2111
# Comedy                1863
# Drama - Thriller      1157
# Drama - Romance       1083
# Horror                 717
# Action - Thriller      693
# Comedy - Drama         656
# Comedy - Romance       569
# Action                 494
# Horror - Thriller      467
# Comedy - Family        429
# Action - Adventure     423
# Thriller               400
# Adventure              326
# Documentary            324
# Crime - Drama          308
# Family                 289
# Crime - Thriller       184
# Action - Drama         139
# Romance                129
# Mystery - Thriller     115
# Western                100
# Animation               93
#                         69
# Science Fiction         59
# Fantasy                 52
# Crime                   45
# Mystery                 36
# Music                   32
# War                     13
# History                  5
# Foreign                  1
# Sci-Fi                   1
# Short                    1
# Name: genre_intersect, dtype: int64

# %%
genre_mapping = {'Drama' : 'Drama', 'Comedy' : 'Comedy', 'Drama - Thriller' : 'Drama - Thriller',
                 'Drama - Romance' : 'Drama - Romance', 'Horror' : 'Horror', 'Action - Thriller' : 'Thriller',
                'Comedy - Drama' : 'Comedy - Drama', 'Comedy - Romance' : 'Comedy - Romance',
                'Action' : 'Action', 'Horror - Thriller' : 'Horror', 'Comedy - Family' : 'Family',
                'Action - Adventure' : 'Action', 'Thriller' : 'Thriller', 'Adventure' : 'Action', 'Documentary' : 'Documentary',
                'Crime - Drama' : 'Drama', 'Family' : 'Family', 'Crime - Thriller' : 'Thriller', 'Action - Drama': 'Action',
                'Romance' :  'Drama - Romance', 'Mystery - Thriller' : 'Thriller', 'Western' : 'Action', 'Animation' : 'Family',
                'Science Fiction' : 'Action', 'Fantasy' : 'Action', 'Crime' : 'Action', 'Mystery' : 'Thriller', 'War' : 'Action',
                'Sci-Fi' : 'Action'}

df = df[(df['genre_intersect'] != '') & (df['genre_intersect'] != 'Music') & (df['genre_intersect'] != 'History') & \
        (df['genre_intersect'] != 'Foreign')  & (df['genre_intersect'] != 'Short')]
df['genre'] = df['genre_intersect'].apply(lambda x: genre_mapping[x])
df['genre'].value_counts()
# Out:
# Drama               2419
# Comedy              1863
# Action              1652
# Thriller            1428
# Drama - Romance     1212
# Horror              1184
# Drama - Thriller    1157
# Family               811
# Comedy - Drama       656
# Comedy - Romance     569
# Documentary          324
# Name: genre, dtype: int64

# %%
# filter out nulls
print(df.shape)
df = df[df['release_date'].notnull() & df['runtime'].notnull() & df['votes'].notnull()]
print(df.shape)
# Out:
# (13275, 38)
# (13156, 38)

# %%
# add additional features
df['release_month'] = pd.to_datetime(df['release_date']).dt.month
df['release_year'] = pd.to_datetime(df['release_date']).dt.year
df['production_companies'] = df['production_companies'].apply(lambda x: len(literal_eval(x)))
df['spoken_languages'] = df['spoken_languages'].apply(lambda x: len(literal_eval(x)))

# %%
# calculate length of text predictor
def get_text_length(text):
    try:
        text = literal_eval(text)
        text = text[0]
        return len(text)
    except:
        return 0

# %%
# get length of text predictors
df['overview_length'] = df['overview'].apply(lambda x: get_text_length(x))
df['tagline_length'] = df['tagline'].apply(lambda x: get_text_length(x))
df['plot_length'] = df['plot'].apply(lambda x: get_text_length(x))
df['plot_outline_length'] = df['plot outline'].apply(lambda x: get_text_length(x))

# %%
# some mpaa ratings were not read properly, this quickly fixes it
def fix_mpaa_rating(rating):
    if rating == 'PG-':
        return 'PG-13'
    elif rating == 'Rated' or rating == 'for' or rating == 'Symbol' or rating == 'G' or rating == 'from' or rating == 'NC-17':
        return 'NR'
    else:
        return rating

# extract mpaa rating
df['mpaa_rating'] = df['mpaa'].apply(lambda x: literal_eval(x)[0].split(' ')[1] if x == x else  None)
df['mpaa_rating'] = df['mpaa_rating'].apply(lambda x: fix_mpaa_rating(x))

# %%
# extract mpaa rating text and length
df ['mpaa_rating_text'] = df.apply(lambda row: row['mpaa'].replace('Rated ' + row['mpaa_rating'] + ' for ', '') if row['mpaa'] == row['mpaa'] else None, axis = 1)
df ['mpaa_rating_text_length'] = df['mpaa_rating_text'].apply(lambda x: get_text_length(x))

# %%
# keep only predictor columns
columns_to_keep = ['part_of_collection', 'budget', 'overview', 'popularity', 'production_companies', 'release_month', 'release_year', 
                   'revenue', 'runtime', 'spoken_languages', 'tagline', 'vote_average', 'vote_count', 'animation department',
                   'art department', 'camera and electrical department', 'cast', 'casting department', 'costume department',
                   'distributors', 'editorial department', 'music department', 'plot', 'plot outline', 'rating',
                   'visual effects', 'votes', 'genre', 'overview_length', 'tagline_length', 'plot_length',
                   'plot_outline_length', 'mpaa_rating_text', 'mpaa_rating_text_length', 'mpaa_rating', 'id']
df_data = df[columns_to_keep]

# %%
df_data.shape
# Out:
# (13156, 36)

# %%
# fill null values
df_data['plot'] = df_data['plot'].fillna('[]')
df_data['plot outline'] = df_data['plot outline'].fillna('[]')
df_data['mpaa_rating_text'] = df_data['mpaa_rating_text'].fillna('[]')
df_data['mpaa_rating'] = df_data['mpaa_rating'].fillna('NR')
df_data = df_data.fillna(0)
# Out:
# C:\Users\Ihsaan Patel\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Ihsaan Patel\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Ihsaan Patel\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Ihsaan Patel\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_data.isnull().sum()
# Out:
# part_of_collection                  0
# budget                              0
# overview                            0
# popularity                          0
# production_companies                0
# release_month                       0
# release_year                        0
# revenue                             0
# runtime                             0
# spoken_languages                    0
# tagline                             0
# vote_average                        0
# vote_count                          0
# animation department                0
# art department                      0
# camera and electrical department    0
# cast                                0
# casting department                  0
# costume department                  0
# distributors                        0
# editorial department                0
# music department                    0
# plot                                0
# plot outline                        0
# rating                              0
# visual effects                      0
# votes                               0
# genre                               0
# overview_length                     0
# tagline_length                      0
# plot_length                         0
# plot_outline_length                 0
# mpaa_rating_text                    0
# mpaa_rating_text_length             0
# mpaa_rating                         0
# id                                  0
# dtype: int64

# %%
# save entire dataset
df_data.to_csv('../Milestone 3/combined_data_clean.csv', index = False)

# %%
# split into train and test sets
train, test = train_test_split(df_data, test_size = 0.3, random_state = 42)
train = train[train['id'] != 21190] # filter out Turkish movie that breaks clustering

# %%
print(train.shape)
print(test.shape)
# Out:
# (9208, 36)
# (3947, 36)

# %%
train['genre'].value_counts()
# Out:
# Drama               1660
# Comedy              1275
# Action              1140
# Thriller             990
# Horror               859
# Drama - Romance      848
# Drama - Thriller     792
# Family               568
# Comedy - Drama       466
# Comedy - Romance     403
# Documentary          207
# Name: genre, dtype: int64

# %%
test['genre'].value_counts()
# Out:
# Drama               738
# Comedy              573
# Action              489
# Thriller            425
# Drama - Thriller    361
# Drama - Romance     355
# Horror              316
# Family              237
# Comedy - Drama      188
# Comedy - Romance    165
# Documentary         100
# Name: genre, dtype: int64

# %%
train.to_csv('../Milestone 3/combined_data_clean_train.csv', index = False)
test.to_csv('../Milestone 3/combined_data_clean_test.csv', index = False)
